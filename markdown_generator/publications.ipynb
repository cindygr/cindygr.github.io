# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
import math
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url	slides_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf	http://academicpages.github.io/files/slides1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf	http://academicpages.github.io/files/slides2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf	http://academicpages.github.io/files/slides3.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd
import math

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("tech_reports.txt", sep="\t", header=0)
publications
# Out:
#    pub_date                                              title  \
# 0    5/2003  A Thesis on a 3D Input Device for Sketching Ch...
# 1    5/2005  Non-Photorealistic Rendering of Algorithmicall...
# 2    5/2005  What a Mesh: Dependent Data Types for Correct ...
# 3    8/2003  Techniques for Non-photorealistic Shading usin...
# 4    8/2006  A Thesis on Sketch-Based Techniques for Mesh D...
# 5    1/2006                  A View-Based Deformation Tool-kit
# 6    6/2007       A Fingerspelling Sign Language Visualization
# 7    5/1998  A Framework for the Synchronous Editingof Mult...
# 8    6/2017          Gender Differences in Robot Teleoperation
# 9    8/2016  Analyzing Human Gaze Patterns During Grasping ...
# 10   8/2016  Advancing Robotic Grasp Planning using Human H...
# 11   3/2017  Modeling a Spectrum of 3D Printed Materials fo...
# 12   8/2007               Perception Guided Image Manipulation
# 13  12/2006  Comparing Features of Three-Dimensional Object...
# 14   8/2012  Modeling Surfaces from Volume Data Using Nonpa...
# 15   8/2013   Shape Correspondence for Biological Applications
# 16  12/2016  Guided Medical Data Segmentation Using Structu...
# 17   6/2018  Developing a 2D Cross-section Training Strateg...
# 18   6/2011     Results of an observational study on sketching
# 19  12/2005   Interactive Manipulation of 3D Scene Projections
# 20   9/2004            Intuitive tools for camera manipulation
# 21  10/2004    Towards a Perception Based image editing System
# 22   6/2004        The IBar: A Perspective-based Camera Widget
# 23   9/2004  Improved Curvature Estimation on Triangular Me...
# 24   0/2003  Using Texture Synthesis for Non-Photorealistic...
# 25   0/2003              Painting Lighting and Viewing Effects
# 26  12/2003       Picture composition for a robot photographer
# 27   1/2002                        View-dependent Texture Maps
# 28  11/2002               Creating View-dependent texture maps
# 29   1/2006  Smooth Surface Reconstruction usingCharts for ...
# 30   5/2006           Smooth Key-framing using the Image Plane
# 31   5/2006  Feature Detection using Curvature Maps and the...
# 32   4/2006                The Real Effect of Warm-Cool Colors
# 33   3/2006       Perceptually Meaningful Image Editing: Depth
# 34   2/2006  Three Dimensional Panoramic Fast Flourescence ...
# 35   4/2009  VolumeViewer: An Interactive Tool for Fitting ...
# 36   6/2008  Local Neighborhoods for Shape Classification a...
# 37   1/2012  Specializing Interfaces for Citizen Science Se...
# 38   5/2007  Comparing Features of Three-Dimensional Object...
# 39   5/2012                Just Draw It! A 3D Sketching System
# 40   4/2007       The Effect of Object Color on Depth Ordering
# 41   3/2016  A Geodesics-based Surface Parameterization to ...
# 42   8/2017  A Taxonomy of Privacy Constructs for Privacy-S...
# 43   8/2016  Human-Planned Robotic Grasp Ranges: Capture an...
# 44   8/2016  Sketched Floor plans versus SLAM maps: A Compa...
# 45   9/2015  Visualization techniques for the developing ch...
# 46   1/2015  Video Manipulation Techniques for the Protecti...
# 47   9/1999      Emerging Challenges in Computational Topology
#
#               url_slug                               venue  \
# 0           tech200320  Washington University in St. Louis
# 1           tech200516  Washington University in St. Louis
# 2           tech200615  Washington University in St. Louis
# 3           tech200362  Washington University in St. Louis
# 4             tech2006  Washington University in St. Louis
# 5             tech2006  Washington Universtiy in St. Louis
# 6         proj207Carol  Washington University in St. Louis
# 7         proj1998matt                    Brown University
# 8    thesis2017Dilruba             Oregon State University
# 9        thesis2016Sai             Oregon State University
# 10   thesis2016Saurabh             Oregon State University
# 11  thesis2017Samantha             Oregon State University
# 12           phd2007rb  Washington University in St. Louis
# 13           phd2007tg  Washington University in St. Louis
# 14         phd2012ross  Washington University in St. Louis
# 15           phd2013Ly  Washington University in St. Louis
# 16     phd2016Michelle  Washington University in St. Louis
# 17      phd2018Anahita             Oregon State University
# 18          tech201157  Washington University in St. Louis
# 19          tech200513  Washington University in St. Louis
# 20          tech200484  Washington University in St. Louis
# 21          tech200465  Washington University in St. Louis
# 22          tech200432  Washington University in St. Louis
# 23           tech20049  Washington University in St. Louis
# 24          tech200354  Washington University in St. Louis
# 25          tech200353  Washington University in St. Louis
# 26          tech200352  Washington University in St. Louis
# 27          tech200210  Washington University in St. Louis
# 28           tech20029  Washington University in St. Louis
# 29          tech200629  Washington University in St. Louis
# 30          tech200628  Washington University in St. Louis
# 31          tech200622  Washington University in St. Louis
# 32          tech200617  Washington University in St. Louis
# 33          tech200611  Washington University in St. Louis
# 34          tech200644  Washington University in St. Louis
# 35          tech200913  Washington University in St. Louis
# 36          tech200815  Washington University in St. Louis
# 37          tech2012SI  Washington University in St. Louis
# 38          tech2007CF  Washington University in St. Louis
# 39         tech1012JDI  Washington University in St. Louis
# 40       tech2007Color  Washington University in St. Louis
# 41         tech2016geo                              Arxive
# 42    tech2017taxonomy                              Arxive
# 43          tech2016RG                              Arxive
# 44         tech2016SKF                              Arxive
# 45         tech2015Viz                              Arxive
# 46  tech2015VideoManip                              Arxive
# 47          tech1999EC                              Arxive
#
#                                               excerpt  url  \
# 0   Tracking a piece of paper as a drawing surface...  NaN
# 1   Combining abstraction and realisim for renderi...  NaN
# 2   Programming language approach to representing ...  NaN
# 3   Non-photorealistic techniques combining shadin...  NaN
# 4   Sketching techniques for meshes, The goal of t...  NaN
# 5   CubeCam for single camera control and a framew...  NaN
# 6   The goal of the Fingerspell Visualization Proj...  NaN
# 7   Published in Eurographics Forum, Curve editing...  NaN
# 8   Published as a paper in Ubiquitous Robots 2018...  NaN
# 9   Published in Symposium on Applied Perception 2...  NaN
# 10  This thesis explores the use of human kinesthe...  NaN
# 11  Soft robotics is an emerging field that heavil...  NaN
# 12  Published in APGV (study on depth ordering),  ...  NaN
# 13  Published in Geometric Modeling and processing...  NaN
# 14  Magnetic resonance imaging: MRI) and computed ...  NaN
# 15  With the tremendous amount of data generated b...  NaN
# 16  Segmentation of 3D/4D biological images is a c...  NaN
# 17  3D volume segmentation is a fundamental proces...  NaN
# 18  Presented as a poster at <a href=\"http://www....  NaN
# 19  Published in  Graphite 2005 as 3D Screen Space...  NaN
# 20  This was published as the CubeCam in Computati...  NaN
# 21  The details on the DKL model,  which represent...  NaN
# 22  The overview of this can be found in the UIST ...  NaN
# 23  Published as Estimating Curvature for Triangul...  NaN
# 24  This was published in Pacific Graphics 2003. T...  NaN
# 25  Published as Painting Lighting and Viewing Eff...  NaN
# 26  This is a detailed look at the framing/composi...  NaN
# 27  Published as Painting Lighting and Viewing Eff...  NaN
# 28  Published as Painting Lighting and Viewing Eff...  NaN
# 29  Published in the Visual Computer,  2009 as Ada...  NaN
# 30  Published in Graphite, 2005, This paper demons...  NaN
# 31  A longer version of the <a href=\"./papers/gmp...  NaN
# 32  A longer version of the <a href=\"./papers/apg...  NaN
# 33  Published in the Visual Computer, 2009, We int...  NaN
# 34  This was published as a <a href=\"https://www....  NaN
# 35  Presented at <a href=\"http://sbim09.cse.wustl...  NaN
# 36  Published in <a href=\"http://www.journals.els...  NaN
# 37  Published as <a href=\"https://link.springer.c...  NaN
# 38  https://openscholarship.wustl.edu/cse_research...  NaN
# 39  Was published in Sketch-based interfaces and M...  NaN
# 40  This is the full version of this <a href=\"htt...  NaN
# 41  Abdominal aortic aneurysm (AAA) intervention a...  NaN
# 42  The introduction of robots into our society wi...  NaN
# 43  A longer version of the AAAI Fall Symposium pa...  NaN
# 44  A longer version of the ICSR \15 paper, Maps -...  NaN
# 45  Longer version of a conference paper published...  NaN
# 46  Systems that give control of a mobile robot to...  NaN
# 47  Here we present the results of the NSF-funded ...  NaN
#
#                               paper_url  \
# 0   http://cindygr.github.io/files/.pdf
# 1   http://cindygr.github.io/files/.pdf
# 2   http://cindygr.github.io/files/.pdf
# 3   http://cindygr.github.io/files/.pdf
# 4   http://cindygr.github.io/files/.pdf
# 5   http://cindygr.github.io/files/.pdf
# 6   http://cindygr.github.io/files/.pdf
# 7   http://cindygr.github.io/files/.pdf
# 8   http://cindygr.github.io/files/.pdf
# 9   http://cindygr.github.io/files/.pdf
# 10  http://cindygr.github.io/files/.pdf
# 11  http://cindygr.github.io/files/.pdf
# 12  http://cindygr.github.io/files/.pdf
# 13  http://cindygr.github.io/files/.pdf
# 14  http://cindygr.github.io/files/.pdf
# 15  http://cindygr.github.io/files/.pdf
# 16  http://cindygr.github.io/files/.pdf
# 17  http://cindygr.github.io/files/.pdf
# 18  http://cindygr.github.io/files/.pdf
# 19  http://cindygr.github.io/files/.pdf
# 20  http://cindygr.github.io/files/.pdf
# 21  http://cindygr.github.io/files/.pdf
# 22  http://cindygr.github.io/files/.pdf
# 23  http://cindygr.github.io/files/.pdf
# 24  http://cindygr.github.io/files/.pdf
# 25  http://cindygr.github.io/files/.pdf
# 26  http://cindygr.github.io/files/.pdf
# 27  http://cindygr.github.io/files/.pdf
# 28  http://cindygr.github.io/files/.pdf
# 29  http://cindygr.github.io/files/.pdf
# 30  http://cindygr.github.io/files/.pdf
# 31  http://cindygr.github.io/files/.pdf
# 32  http://cindygr.github.io/files/.pdf
# 33  http://cindygr.github.io/files/.pdf
# 34  http://cindygr.github.io/files/.pdf
# 35  http://cindygr.github.io/files/.pdf
# 36  http://cindygr.github.io/files/.pdf
# 37  http://cindygr.github.io/files/.pdf
# 38  http://cindygr.github.io/files/.pdf
# 39  http://cindygr.github.io/files/.pdf
# 40  http://cindygr.github.io/files/.pdf
# 41                                  NaN
# 42                                  NaN
# 43                                  NaN
# 44                                  NaN
# 45                                  NaN
# 46                                  NaN
# 47                                  NaN
#
#                                              citation  slides_url
# 0                                     Mark Schroering         NaN
# 1                                       Nathan Dudley         NaN
# 2                                         Joel Brandt         NaN
# 3                                      Reynold Bailey         NaN
# 4                                       Raquel Bujans         NaN
# 5                                    Nisha Sudarsanam         NaN
# 6                                      Carol Brickman         NaN
# 7                                       Matthew Ayers         NaN
# 8                                     Dilruba Showkat         NaN
# 9                                  Sai Krishna Allani         NaN
# 10                               Saurabh Milind Dixit         NaN
# 11                                  Samantha Hemleben         NaN
# 12                                     Reynold Bailey         NaN
# 13                               Timothy David Gatzke         NaN
# 14                                        Ross Sowell         NaN
# 15                                            Ly Phan         NaN
# 16                          Michelle Vaughan Holloway         NaN
# 17                                  Anahita Sanandaji         NaN
# 18                                        Cindy Grimm         NaN
# 19  Patrick Coleman and Leon Barrett and Cindy Gri...         NaN
# 20   Nisha Sudarsanam and Cindy Grimm and Karan Singh         NaN
# 21   Reynold Bailey and Raquel Bujans and Cindy Grimm         NaN
# 22   Cindy Grimm and Karan Singh and Nisha Sudarsanam         NaN
# 23                         Tim Gatzke and Cindy Grimm         NaN
# 24  Christopher Kulla and James (Jayne) Tucek and ...         NaN
# 25                                        Cindy Grimm         NaN
# 26    Michael Dixon and Cindy Grimm and William Smart         NaN
# 27                                    No presentation         NaN
# 28                   Cindy Grimm and Michael Kowalski         NaN
# 29                             Cindy Grimm and Tao Ju         NaN
# 30                       Leon Barrett and Cindy Grimm         NaN
# 31                     Timothy Gatzke and Cindy Grimm         NaN
# 32  Reynold Bailey and Cindy Grimm and Christopher...         NaN
# 33                     Reynold Bailey and Cindy Grimm         NaN
# 34  Fujian Qu and Vladimir Nikolski and Cindy Grim...         NaN
# 35  Ross Sowell and Lu Liu and Tao Ju and Cindy Gr...         NaN
# 36                      Cindy Grimm and William Smart         NaN
# 37  Michelle Vaughan and Cindy Grimm and Ross Sowe...         NaN
# 38                     Timothy Gatzke and Cindy Grimm         NaN
# 39                      Cindy Grimm and Pushkar Joshi         NaN
# 40  Reynold Bailey and Cindy Grimm and Christopher...         NaN
# 41  Ly Phan and Katherine Courchaine and Amir Azar...         NaN
# 42  Matthew Rueben and Cindy M. Grimm and Frank J....         NaN
# 43  Brendon John and Jackson Carter and Javier Rui...         NaN
# 44  Leo Bowen-Biggs and Suzanne Dazo and Yili Zhan...         NaN
# 45         Ly Phan and Sandra Rugonyi and Cindy Grimm         NaN
# 46  Alexander Hubers and Emily Andrulis and Levi S...         NaN
# 47  Marshall W. Bern and David Eppstein and Pankaj...         NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    print(f"{item.pub_date}")
    if row > 12:
        break
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""

    md += """\ncategory: arxive"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.slides_url)) > 5:
        md += "\nslidesurl: '" + item.slides_url + "'"

    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        str_exceprt = item.excerpt[0:-2]
        md += "\n" + html_escape(str_exceprt) + "\n"

    if len(str(item.slides_url)) > 5:
        md += "\n[Download slides here](" + item.slides_url + ")\n" 

    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nauthors: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# 5/2003
# 5/2005
# 5/2005
# 8/2003
# 8/2006
# 1/2006
# 6/2007
# 5/1998
# 6/2017
# 8/2016
# 8/2016
# 3/2017
# 8/2007
# 12/2006

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 1995-is1995sis.md
# 1995-sig1995msat.md
# 1995-uist1995vism.md
# 1998-01-01-A-Framework-for-Synchronized-Editing-of-Multiple-Curve-Representations.md
# 1998-is1999ig.md
# 1998-sig1998mf.md
# 2001-euro2001prc.md
# 2001-ieeeVis2001mv.md
# 2002-01-01-Fitting-manifold-surfaces-to-three-dimensional-point-clouds.md
# 2002-smi2002sm.md
# 2002-wcb2002ca.md
# 2003-aaai2003ni.md
# 2003-iaai2003sc.md
# 2003-iros2003arp.md
# 2003-ms2003pt.md
# 2003-pg2003uts.md
# 2003-vi20033Dp.md
# 2003-vi2003nid.md
# 2004-01-01-Estimating-Joint-Contact-Areas-and-Ligament-Lengths-from-Bone-Kinematics-and-Surfaces.md
# 2004-01-01-Parameterization-using-manifolds.md
# 2004-01-01-Say-cheese-Experiences-with-a-robot-photographer.md
# 2004-uist2004IBar.md
# 2005-01-01-Implementing-the-IBar-camera-widget.md
# 2005-euro2005imp.md
# 2005-euro2005tl.md
# 2005-g2005hm.md
# 2005-g2005nl.md
# 2005-smi2005cm.md
# 2006-01-01-Estimating-curvature-on-triangular-meshes.md
# 2006-01-01-Interactive-decal-compositing-with-discrete-exponential-maps.md
# 2006-apgv2006wc.md
# 2006-gmp2006fd.md
# 2006-sbim2006rd.md
# 2006-tech200718.md
# 2007-01-01-Arthrodial-joint-markerless-cross-parameterization-and-biomechanical-visualization.md
# 2007-01-01-Camera-Keyframing-using-Linear-Interpolation-of-Matrices.md
# 2007-01-01-Continuous-Cube-Mapping.md
# 2007-01-01-Perceptually-meaningful-image-editing-Manipulating-perceived-depth-and-creating-the-illusion-of-motion-in-2D-images.md
# 2007-01-01-Table-top-computed-lighting-for-practical-digital-photography.md
# 2007-01-01-Three-dimensional-panoramic-imaging-of-cardiac-arrhythmias-in-rabbit-heart.md
# 2007-grapp2007npt.md
# 2007-grapp2007vdp.md
# 2008-01-01-A-sketch-based-user-interface-for-reconstructing-architectural-drawings.md
# 2008-apgv2008gd.md
# 2008-npar2008np.md
# 2009-01-01-Adaptive-smooth-surface-fitting-with-manifolds.md
# 2009-01-01-Search-task-performance-using-subtle-gaze-direction-with-the-presence-of-distractions.md
# 2009-01-01-Subtle-gaze-direction.md
# 2009-ca2009cc.md
# 2009-ca2009lv.md
# 2009-sbim2009cs.md
# 2009-sbim2009ls.md
# 2010-01-01-A-new-method-to-measure-cortical-growth-in-the-developing-brain.md
# 2010-01-01-Experiences-with-active-learning-in-CS-3.md
# 2010-01-01-The-active-learning-transformation-a-case-study-in-software-development-and-systems-software-courses.md
# 2010-icrt2010as.md
# 2010-spm2010pe.md
# 2011-01-01-Shape-Space-Analysis-of-Structures-in-Bat-Biosonar.md
# 2011-01-01-Shape-classification-and-normal-estimation-for-non-uniformly-sampled-noisy-point-data.md
# 2011-asme2011bio.md
# 2011-egor2011lsd.md
# 2011-egor2011sr.md
# 2011-i3d2011ci.md
# 2011-sbim2011ss.md
# 2012-01-01-Comparing-local-shape-descriptors.md
# 2012-01-01-Scattergather-clustering-Flexibly-incorporating-user-feedback-to-steer-clustering-results.md
# 2012-apgv2012dg.md
# 2012-etra2012isg.md
# 2012-etra2012sgm.md
# 2012-sbim2012jdi.md
# 2013-01-01-Statistical-analysis-of-manual-segmentations-of-structures-in-medical-images.md
# 2013-apgv2013ga.md
# 2013-sbim2013sp.md
# 2015-icsr2015vm.md
# 2015-isvc2015gs.md
# 2015-isvc2015vt.md
# 2016-AAAI2016hp.md
# 2016-apgv2016eh.md
# 2016-etra2016el.md
# 2016-ev2016is.md
# 2016-ic2016ete.md
# 2016-icra2016vc.md
# 2016-icsr2016maps.md
# 2016-roman2016privacy.md
# 2017-apgv2017icc.md
# 2017-eaai2017reu.md
# 2017-hri2017pc.md
# 2017-wr2017mh.md
# 2018-aiethics2018em.md
# 2018-icra2018gc.md
# 2018-icra2018go.md
# 2018-icraw2018gm.md
# 2018-rgw2019idd.md
# 2018-rss2018dnc.md
# 2019-icsr2019gf.md
# 2024-02-17-paper-title-number-4.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# slidesurl: 'http://academicpages.github.io/files/slides1.pdf'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download slides here](http://academicpages.github.io/files/slides1.pdf)
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
