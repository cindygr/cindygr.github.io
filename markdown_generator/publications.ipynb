# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url	slides_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf	http://academicpages.github.io/files/slides1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf	http://academicpages.github.io/files/slides2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf	http://academicpages.github.io/files/slides3.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("Conferences.txt", sep="\t", header=0)
publications
# Out:
#    pub_date                                              title      url_slug  \
# 0   11/2005  3D Screen-space Widgets for Non-linear Projection       g2005nl
# 1   11/2005  Spherical Manifolds for Adaptive Resolution Su...       g2005hm
# 2    9/2005  Interactive Manipulation of Projections with a...   euro2005imp
# 3    6/2005          Curvature Maps for Local Shape Comparison     smi2005cm
# 4   10/2004        The IBar: A Perspective-based Camera Widget  uist2004IBar
# ..      ...                                                ...           ...
# 64   5/2018  Instrumented Door and Drawer for Comprehensive...    rgw2019idd
# 65   5/2018   A Grasping Metric based on Hand-Object Collision   icraw2018gm
# 66   6/2018     Dataset for Near Contact Grasping Trajectories    rss2018dnc
# 67   2/2017           A summer research experience in robotics   eaai2017reu
# 68   8/2016  Interpreting Survey Items using Exploratory Fa...      ev2016is
#
#                                                 venue  \
# 0   Proceedings of the 3rd International Conferenc...
# 1   Proceedings of the 3rd International Conferenc...
# 2                              EG Short Presentations
# 3   International Conference on Shape Modeling and...
# 4   Proceedings of the 17th annual ACM symposium o...
# ..                                                ...
# 64  IROS Experimental Robotic Grasping and Manipul...
# 65  ICRA Workshop on Multimodal Robot Perception: ...
# 66  Robotics: Science and Systems,  New Benchmarks...
# 67  The Seventh Symposium on Educational Advances ...
# 68  Second International Workshop on Evaluation Me...
#
#                                               excerpt  \
# 0   This paper lets the user specify multiple came...
# 1   Spherical shape modeling using a hierarchical ...
# 2   A specific type of non-linear projection that ...
# 3   A local shape comparison technique for meshes,...
# 4   The first draft of the IBar. <a href=\"./IBar\...
# ..                                                ...
# 64  Creating a door/drawer that can be opened/clos...
# 65  Look at the space between the hand and the obj...
# 66  To date the design of grasping metrics has lar...
# 67  A summary of the philosophy we use when runnin...
# 68  How to take apart a survey to get started unde...
#
#                                                   url  \
# 0          http://doi.acm.org/10.1145/1101389.1101433
# 1          http://doi.acm.org/10.1145/1101389.1101425
# 2   https://diglib.eg.org/handle/10.2312/egs.20051...
# 3        https://ieeexplore.ieee.org/document/1563230
# 4         http://www.acm.org/uist/uist2004/index.html
# ..                                                ...
# 64        http://rpal.cse.usf.edu/workshop_iros_2018/
# 65  https:/atanaso.github.io/rcw-icra18/assets/ref...
# 66  https:/atanaso.github.io/rcw-icra18/assets/ref...
# 67  https://www.aaai.org/ocs/index.php/AAAI/AAAI17...
# 68          https://sites.google.com/site/emshri2016/
#
#                                           paper_url  \
# 0        http://cindygr.github.io/files/g2005nl.pdf
# 1        http://cindygr.github.io/files/g2005hm.pdf
# 2    http://cindygr.github.io/files/euro2005imp.pdf
# 3      http://cindygr.github.io/files/smi2005cm.pdf
# 4   http://cindygr.github.io/files/uist2004IBar.pdf
# ..                                              ...
# 64                                              NaN
# 65                                              NaN
# 66                                              NaN
# 67                                              NaN
# 68                                              NaN
#
#                                              citation  slides_url
# 0   Leon Barrett and Patrick Coleman and Nisha Sud...         NaN
# 1                                         Cindy Grimm         NaN
# 2    Nisha Sudarsanam and Cindy Grimm and Karan Singh         NaN
# 3   Timothy Gatzke and Steve Zelinka and Cindy Gri...         NaN
# 4    Karan Singh and Cindy Grimm and Nisha Sudarsanam         NaN
# ..                                                ...         ...
# 64  Kristan Hilby and John Morrow and Yi Herng Ong...         NaN
# 65  Matthew Sundberg and Ryan Sherman and Ammar Ko...         NaN
# 66  Ammar Kothari and Yi Ong and John Morrow and R...         NaN
# 67  Cindy Grimm and Alicia Lyman-Holt and William ...         NaN
# 68  Matthew Rueben and Frank J. Bernieri and Cindy...         NaN
#
# [69 rows x 9 columns]

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""

    md += """\ncategory: conferences"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.slides_url)) > 5:
        md += "\nslidesurl: '" + item.slides_url + "'"

    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        str_exceprt = item.excerpt[0:-2]
        md += "\n" + html_escape(str_exceprt) + "\n"

    if len(str(item.slides_url)) > 5:
        md += "\n[Download slides here](" + item.slides_url + ")\n" 

    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nauthors: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 1995-is1995sis.md
# 1995-sig1995msat.md
# 1995-uist1995vism.md
# 1998-01-01-A-Framework-for-Synchronized-Editing-of-Multiple-Curve-Representations.md
# 1998-is1999ig.md
# 1998-sig1998mf.md
# 2001-euro2001prc.md
# 2001-ieeeVis2001mv.md
# 2002-01-01-Fitting-manifold-surfaces-to-three-dimensional-point-clouds.md
# 2002-smi2002sm.md
# 2002-wcb2002ca.md
# 2003-aaai2003ni.md
# 2003-iaai2003sc.md
# 2003-iros2003arp.md
# 2003-ms2003pt.md
# 2003-pg2003uts.md
# 2003-vi20033Dp.md
# 2003-vi2003nid.md
# 2004-01-01-Estimating-Joint-Contact-Areas-and-Ligament-Lengths-from-Bone-Kinematics-and-Surfaces.md
# 2004-01-01-Parameterization-using-manifolds.md
# 2004-01-01-Say-cheese-Experiences-with-a-robot-photographer.md
# 2004-uist2004IBar.md
# 2005-01-01-Implementing-the-IBar-camera-widget.md
# 2005-euro2005imp.md
# 2005-euro2005tl.md
# 2005-g2005hm.md
# 2005-g2005nl.md
# 2005-smi2005cm.md
# 2006-01-01-Estimating-curvature-on-triangular-meshes.md
# 2006-01-01-Interactive-decal-compositing-with-discrete-exponential-maps.md
# 2006-apgv2006wc.md
# 2006-gmp2006fd.md
# 2006-sbim2006rd.md
# 2006-tech200718.md
# 2007-01-01-Arthrodial-joint-markerless-cross-parameterization-and-biomechanical-visualization.md
# 2007-01-01-Camera-Keyframing-using-Linear-Interpolation-of-Matrices.md
# 2007-01-01-Continuous-Cube-Mapping.md
# 2007-01-01-Perceptually-meaningful-image-editing-Manipulating-perceived-depth-and-creating-the-illusion-of-motion-in-2D-images.md
# 2007-01-01-Table-top-computed-lighting-for-practical-digital-photography.md
# 2007-01-01-Three-dimensional-panoramic-imaging-of-cardiac-arrhythmias-in-rabbit-heart.md
# 2007-grapp2007npt.md
# 2007-grapp2007vdp.md
# 2008-01-01-A-sketch-based-user-interface-for-reconstructing-architectural-drawings.md
# 2008-apgv2008gd.md
# 2008-npar2008np.md
# 2009-01-01-Adaptive-smooth-surface-fitting-with-manifolds.md
# 2009-01-01-Search-task-performance-using-subtle-gaze-direction-with-the-presence-of-distractions.md
# 2009-01-01-Subtle-gaze-direction.md
# 2009-ca2009cc.md
# 2009-ca2009lv.md
# 2009-sbim2009cs.md
# 2009-sbim2009ls.md
# 2010-01-01-A-new-method-to-measure-cortical-growth-in-the-developing-brain.md
# 2010-01-01-Experiences-with-active-learning-in-CS-3.md
# 2010-01-01-The-active-learning-transformation-a-case-study-in-software-development-and-systems-software-courses.md
# 2010-icrt2010as.md
# 2010-spm2010pe.md
# 2011-01-01-Shape-Space-Analysis-of-Structures-in-Bat-Biosonar.md
# 2011-01-01-Shape-classification-and-normal-estimation-for-non-uniformly-sampled-noisy-point-data.md
# 2011-asme2011bio.md
# 2011-egor2011lsd.md
# 2011-egor2011sr.md
# 2011-i3d2011ci.md
# 2011-sbim2011ss.md
# 2012-01-01-Comparing-local-shape-descriptors.md
# 2012-01-01-Scattergather-clustering-Flexibly-incorporating-user-feedback-to-steer-clustering-results.md
# 2012-apgv2012dg.md
# 2012-etra2012isg.md
# 2012-etra2012sgm.md
# 2012-sbim2012jdi.md
# 2013-01-01-Statistical-analysis-of-manual-segmentations-of-structures-in-medical-images.md
# 2013-apgv2013ga.md
# 2013-sbim2013sp.md
# 2015-icsr2015vm.md
# 2015-isvc2015gs.md
# 2015-isvc2015vt.md
# 2016-AAAI2016hp.md
# 2016-apgv2016eh.md
# 2016-etra2016el.md
# 2016-ev2016is.md
# 2016-ic2016ete.md
# 2016-icra2016vc.md
# 2016-icsr2016maps.md
# 2016-roman2016privacy.md
# 2017-apgv2017icc.md
# 2017-eaai2017reu.md
# 2017-hri2017pc.md
# 2017-wr2017mh.md
# 2018-aiethics2018em.md
# 2018-icra2018gc.md
# 2018-icra2018go.md
# 2018-icraw2018gm.md
# 2018-rgw2019idd.md
# 2018-rss2018dnc.md
# 2019-icsr2019gf.md
# 2024-02-17-paper-title-number-4.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# slidesurl: 'http://academicpages.github.io/files/slides1.pdf'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download slides here](http://academicpages.github.io/files/slides1.pdf)
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
